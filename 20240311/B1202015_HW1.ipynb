# %%
print('''I'm a student''')
# Out:
# I'm a student

# %%
import math
x1 = eval(input('x1='))
y1 = eval(input('y1='))
x2 = eval(input('x2='))
y2 = eval(input('y2='))
print(math.sqrt((x1-x2)**2+(y1-y2)**2))
# Out:
# x1=0
# y1=0
# x2=3
# y2=4
# 5.0

# %%
h = eval(input('height(cm)='))
h /= 100
w = eval(input('weight(kg)='))
print(w/((h)**2))
# Out:
# height(cm)=100
# weight(kg)=50
# 50.0
